# %%
import torch

if torch.cuda.is_available():
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available, using CPU")
# Out:
# Using GPU: NVIDIA GeForce RTX 2070 SUPER

# %%
# Our proposed model 100 epochs training on MNIST (anomaly detection) V3
# The codes follows our proposed algorithm desgin
# digits 2 and 3 are anomaly numbers
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import copy
import numpy as np
import os
import torch.nn.functional as F
import torch.utils.data.dataloader as dataloader
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch.autograd import Variable
from torchvision import transforms
from torchvision.datasets import CelebA
from torch import optim
from torch.utils import data as dataloader


# Set the random seed and device
SEED = 1
torch.manual_seed(SEED)
cuda = torch.cuda.is_available()
device = torch.device('cuda' if cuda else 'cpu')
SAVE_PATH = r"F:\rPPGdata_4\MNIST\best_model_CelebA_parallel_desktop2070.pth"
#best_model_path = r"F:\rPPGdata_4\MNIST\best_model_MNIST_parallel_desktop2070.pth"
BATCH_SIZE = 128
Z_DIM = 300
LOG_INTERVAL = 50

# Define the transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

# Remove digits 2 and 3 from the training dataset
train_dataset.data = train_dataset.data[(train_dataset.targets != 2) & (train_dataset.targets != 3)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets != 2) & (train_dataset.targets != 3)]

# # Remove digits 2 and 3 from the test dataset
# test_dataset.data = test_dataset.data[(test_dataset.targets != 2) & (test_dataset.targets != 3)]
# test_dataset.targets = test_dataset.targets[(test_dataset.targets != 2) & (test_dataset.targets != 3)]

# Create new data loaders after removing digits 2 and 3
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)


def plot_images(original_images, reconstructed_images, n=10):
    original_images = original_images.cpu().numpy().squeeze()
    reconstructed_images = reconstructed_images.cpu().detach().numpy().squeeze()

    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Display original images
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(original_images[i], cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstruction images
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(reconstructed_images[i], cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()


# Define the GumbelSoftmaxVAE model
class GumbelSoftmaxVAE(nn.Module):
    def __init__(self, tau_1=1.0, tau_2=1.0):
        super().__init__()

        self.tau_1 = tau_1
        self.tau_2 = tau_2

        # Encoder
        self.conv1 = nn.Conv2d(1, 32, kernel_size=4, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1)

        # Two layers of latent variables
        self.fc_logits_z1 = nn.Linear(256 * 4 * 4, Z_DIM)
        self.fc_logits_z2 = nn.Linear(Z_DIM, Z_DIM)

        # Decoder for each layer
        self.fc_dec1 = nn.Linear(Z_DIM, 256 * 4 * 4)
        self.fc_dec2 = nn.Linear(Z_DIM, 128 * 8 * 8)

        self.conv_trans1_1 = nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1)
        self.conv_trans2_1 = nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1)
        self.conv_trans3_1 = nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1)
        self.conv_trans4_1 = nn.ConvTranspose2d(32, 1, kernel_size=4, stride=2, padding=1)

        self.conv_trans1_2 = nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1)
        self.conv_trans2_2 = nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1)
        self.conv_trans3_2 = nn.ConvTranspose2d(32, 1, kernel_size=4, stride=2, padding=1)

    def encode(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = x.view(x.size(0), -1)

        logits_z1 = self.fc_logits_z1(x)
        logits_z2 = self.fc_logits_z2(logits_z1)

        return logits_z1, logits_z2

    def reparameterize(self, logits, tau):
        gumbel_noise = torch.rand_like(logits).to(device)
        gumbel_noise = -torch.log(-torch.log(gumbel_noise + 1e-8) + 1e-8)
        z = (logits + gumbel_noise) / tau
        z = F.softmax(z, dim=-1)
        return z


    def decode1(self, z):
        z = self.fc_dec1(z)
        z = z.view(z.size(0), 256, 4, 4)  # reshape
        z = F.relu(self.conv_trans1_1(z))
        z = F.relu(self.conv_trans2_1(z))
        z = F.relu(self.conv_trans3_1(z))
        z = torch.tanh(self.conv_trans4_1(z))
        z = torch.clamp(z, 0, 1)  # Clamp the values between 0 and 1
        return z

    def decode2(self, z):
        z = self.fc_dec2(z)
        z = z.view(z.size(0), 128, 8, 8)  # reshape
        z = F.relu(self.conv_trans1_2(z))
        z = F.relu(self.conv_trans2_2(z))
        z = torch.sigmoid(self.conv_trans3_2(z))
        z = torch.clamp(z, 0, 1)  # Clamp the values between 0 and 1
        return z

    def forward(self, x):
        logits_z1, logits_z2 = self.encode(x)
        z1 = self.reparameterize(logits_z1, self.tau_1)
        z2 = self.reparameterize(logits_z2, self.tau_2)

        x_hat1 = self.decode1(z1)
        x_hat2 = self.decode2(z2)

        # Average the output of the two decoders
        x_hat = (x_hat1 + x_hat2) / 2.0

        return x_hat, logits_z1, logits_z2, z1, z2

    def gumbel_softmax_loss_function(self, recon_x, x, logits_z1, logits_z2, z1, z2):
        # Clamp the values of recon_x between 0 and 1
        recon_x = torch.clamp(recon_x, 0, 1)
        # Binary cross entropy
        xent_loss = F.binary_cross_entropy(recon_x, x, reduction='none')
        xent_loss = torch.sum(xent_loss,dim=[1, 2, 3])

        # KL divergence for each layer
        p_z1 = F.softmax(logits_z1, dim=-1)
        p_z1 = torch.clamp(p_z1, torch.finfo(p_z1.dtype).eps, 1. - torch.finfo(p_z1.dtype).eps)  # to prevent log(0)
        kl_loss_z1 = torch.sum(p_z1 * torch.log(p_z1 * Z_DIM + torch.finfo(p_z1.dtype).eps), dim=-1)

        p_z2 = F.softmax(logits_z2, dim=-1)
        p_z2 = torch.clamp(p_z2, torch.finfo(p_z2.dtype).eps, 1. - torch.finfo(p_z2.dtype).eps)  # to prevent log(0)
        kl_loss_z2 = torch.sum(p_z2 * torch.log(p_z2 * Z_DIM + torch.finfo(p_z2.dtype).eps), dim=-1)

        # Total loss is the sum of the losses for each layer
        vae_loss = torch.mean(xent_loss + kl_loss_z1 + kl_loss_z2)
        return vae_loss

initial_tau_1 = 1.0
initial_tau_2 = 1.0
NUM_EPOCHS = 120
LOG_INTERVAL = 50
NUM_MODELS = 10
LOSS_THRESHOLD = 0.0001

# Initialize models and optimizers
models = [GumbelSoftmaxVAE().to(device) for _ in range(NUM_MODELS)]
optimizers = [optim.Adam(model.parameters(), lr=1e-3) for model in models]

best_tau_per_epoch_1 = []  # To record the best tau_1 for each epoch
best_tau_per_epoch_2 = []  # To record the best tau_2 for each epoch

# Initialize temperature strategies
initial_taus = [1.0 for _ in range(NUM_MODELS)]
temp_strategies = ['fixed', 'linear_increase', 'linear_decrease', 'exp_increase', 'exp_decrease']
temp_strategies_extended = ['fixed'] + temp_strategies * ((NUM_MODELS - 1) // len(temp_strategies)) + temp_strategies[:((NUM_MODELS - 1) % len(temp_strategies))]
tau_min, tau_max = 0.5, 300
lin_increase, lin_decrease = 1.0, 0.01
exp_increase, exp_decrease = 1.05, 0.99
learning_rate = 0.01
patience_threshold = 5
patience_counter = [0 for _ in range(NUM_MODELS)]

# Ensure temp_strategies_extended has correct length
assert len(temp_strategies_extended) == NUM_MODELS, f"Expected {NUM_MODELS} strategies, got {len(temp_strategies_extended)}"

best_global_loss = float('inf')  # Initialize the best global loss with infinity

for epoch in range(NUM_EPOCHS):
    losses = []
    best_reconstruction = None
    original_images = None

    for i in range(NUM_MODELS):
        model = models[i]
        temp_strategy = temp_strategies_extended[i]

        if temp_strategy == 'fixed':
            model.tau_1 = nn.Parameter(torch.tensor(float(initial_taus[i])), requires_grad=True)
            model.tau_2 = nn.Parameter(torch.tensor(float(initial_taus[i])), requires_grad=True)
        elif temp_strategy == 'linear_increase':
            model.tau_1 = nn.Parameter(torch.tensor(float(min(initial_taus[i] + epoch * lin_increase, tau_max))), requires_grad=True)
            model.tau_2 = nn.Parameter(torch.tensor(float(min(initial_taus[i] + epoch * lin_increase, tau_max))), requires_grad=True)
        elif temp_strategy == 'linear_decrease':
            model.tau_1 = nn.Parameter(torch.tensor(float(max(initial_taus[i] - epoch * lin_decrease, tau_min))), requires_grad=True)
            model.tau_2 = nn.Parameter(torch.tensor(float(max(initial_taus[i] - epoch * lin_decrease, tau_min))), requires_grad=True)
        elif temp_strategy == 'exp_increase':
            model.tau_1 = nn.Parameter(torch.tensor(float(min(initial_taus[i] * (exp_increase ** epoch), tau_max))), requires_grad=True)
            model.tau_2 = nn.Parameter(torch.tensor(float(min(initial_taus[i] * (exp_increase ** epoch), tau_max))), requires_grad=True)
        elif temp_strategy == 'exp_decrease':
            model.tau_1 = nn.Parameter(torch.tensor(float(max(initial_taus[i] * (exp_decrease ** epoch), tau_min))), requires_grad=True)
            model.tau_2 = nn.Parameter(torch.tensor(float(max(initial_taus[i] * (exp_decrease ** epoch), tau_min))), requires_grad=True)

        epoch_loss = 0.0

        for batch_idx, (data, _) in enumerate(train_loader):
            data = data.to(device)
            optimizers[i].zero_grad()
            recon_batch, logits_z1, logits_z2, z1, z2 = model(data)
            loss = model.gumbel_softmax_loss_function(recon_batch, data, logits_z1, logits_z2, z1, z2)
            loss.backward()
            optimizers[i].step()
            epoch_loss += loss.item()

            if epoch_loss < LOSS_THRESHOLD and (best_reconstruction is None or loss.item() < min(losses)):
                best_reconstruction = recon_batch
                original_images = data

        epoch_loss /= len(train_loader)
        losses.append(epoch_loss)
        print(f'Train Epoch: {epoch} \tModel: {i} \tTraining Loss: {epoch_loss} \tTemperature Strategy: {temp_strategy} \ttau_1: {model.tau_1.item()} \ttau_2: {model.tau_2.item()}')

    best_model_idx = np.argmin(losses)
    best_loss = losses[best_model_idx]

    # Check if the current best loss is better than the global best loss
    if best_loss < best_global_loss:
        best_global_loss = best_loss
        best_model_state_dict = copy.deepcopy(models[best_model_idx].state_dict())
        torch.save(models[best_model_idx].state_dict(), SAVE_PATH)  # Save the best model
        print(f'Best model saved with index: {best_model_idx} and loss: {best_loss}')

    for i in range(NUM_MODELS):
        if i != best_model_idx:
            if losses[i] > best_loss:
                patience_counter[i] += 1
                if patience_counter[i] >= patience_threshold:
                    delta_tau = learning_rate * (losses[i] - best_loss) # positive item
                    models[i].tau_1 = nn.Parameter(torch.tensor(float(min(models[i].tau_1.item() + delta_tau, tau_max))), requires_grad=True)
                    models[i].tau_2 = nn.Parameter(torch.tensor(float(min(models[i].tau_2.item() + delta_tau, tau_max))), requires_grad=True)
                    patience_counter[i] = 0

    best_tau_per_epoch_1.append(models[best_model_idx].tau_1.item())
    best_tau_per_epoch_2.append(models[best_model_idx].tau_2.item())

    print(f'Epoch: {epoch} \tBest Model Index: {best_model_idx} \tBest Temperature Strategy: {temp_strategies_extended[best_model_idx]} \tBest tau_1: {models[best_model_idx].tau_1.item()} \tBest tau_2: {models[best_model_idx].tau_2.item()}')

    if best_reconstruction is not None and original_images is not None:
        plot_images(original_images.cpu(), best_reconstruction.cpu())

# Output the best tau for each epoch
for epoch, (tau_1, tau_2) in enumerate(zip(best_tau_per_epoch_1, best_tau_per_epoch_2)):
    print(f"Epoch: {epoch}, Best Tau 1: {tau_1}, Best Tau 2: {tau_2}")

# Plot the best_tau_per_epoch
plt.figure(figsize=(12, 8))
plt.plot(range(NUM_EPOCHS), best_tau_per_epoch_1, label='Best Tau 1 per Epoch')
plt.plot(range(NUM_EPOCHS), best_tau_per_epoch_2, label='Best Tau 2 per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Tau values')
plt.title('Best Tau Values per Epoch')
plt.legend()
plt.show()
# Out:
# Train Epoch: 0 	Model: 0 	Training Loss: 1110.3408072916666 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 1 	Training Loss: 923.53473828125 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 2 	Training Loss: 861.8771399739584 	Temperature Strategy: linear_increase 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 3 	Training Loss: 889.8464135742188 	Temperature Strategy: linear_decrease 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 4 	Training Loss: 864.8321749674479 	Temperature Strategy: exp_increase 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 5 	Training Loss: 915.3170690104166 	Temperature Strategy: exp_decrease 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 6 	Training Loss: 936.6512241210937 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 7 	Training Loss: 863.8594127604167 	Temperature Strategy: linear_increase 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 8 	Training Loss: 907.436509765625 	Temperature Strategy: linear_decrease 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 0 	Model: 9 	Training Loss: 897.5240120442709 	Temperature Strategy: exp_increase 	tau_1: 1.0 	tau_2: 1.0
# Best model saved with index: 2 and loss: 861.8771399739584
# Epoch: 0 	Best Model Index: 2 	Best Temperature Strategy: linear_increase 	Best tau_1: 1.0 	Best tau_2: 1.0
# Train Epoch: 1 	Model: 0 	Training Loss: 1063.320407389323 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 1 	Model: 1 	Training Loss: 710.8037364908854 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 1 	Model: 2 	Training Loss: 583.5440861816406 	Temperature Strategy: linear_increase 	tau_1: 2.0 	tau_2: 2.0
# Train Epoch: 1 	Model: 3 	Training Loss: 664.7442220052084 	Temperature Strategy: linear_decrease 	tau_1: 0.9900000095367432 	tau_2: 0.9900000095367432
# Train Epoch: 1 	Model: 4 	Training Loss: 664.4999685872396 	Temperature Strategy: exp_increase 	tau_1: 1.0499999523162842 	tau_2: 1.0499999523162842
# Train Epoch: 1 	Model: 5 	Training Loss: 768.1349272460938 	Temperature Strategy: exp_decrease 	tau_1: 0.9900000095367432 	tau_2: 0.9900000095367432
# Train Epoch: 1 	Model: 6 	Training Loss: 771.1659560546875 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 1 	Model: 7 	Training Loss: 584.2954916992187 	Temperature Strategy: linear_increase 	tau_1: 2.0 	tau_2: 2.0
# Train Epoch: 1 	Model: 8 	Training Loss: 697.3824269205729 	Temperature Strategy: linear_decrease 	tau_1: 0.9900000095367432 	tau_2: 0.9900000095367432
# Train Epoch: 1 	Model: 9 	Training Loss: 760.7310037434896 	Temperature Strategy: exp_increase 	tau_1: 1.0499999523162842 	tau_2: 1.0499999523162842
# Best model saved with index: 2 and loss: 583.5440861816406
# Epoch: 1 	Best Model Index: 2 	Best Temperature Strategy: linear_increase 	Best tau_1: 2.0 	Best tau_2: 2.0
# Train Epoch: 2 	Model: 0 	Training Loss: 1067.5230756835938 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 2 	Model: 1 	Training Loss: 678.452801595052 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 2 	Model: 2 	Training Loss: 482.7793604329427 	Temperature Strategy: linear_increase 	tau_1: 3.0 	tau_2: 3.0
# Train Epoch: 2 	Model: 3 	Training Loss: 636.7778966471354 	Temperature Strategy: linear_decrease 	tau_1: 0.9800000190734863 	tau_2: 0.9800000190734863
# Train Epoch: 2 	Model: 4 	Training Loss: 628.368892578125 	Temperature Strategy: exp_increase 	tau_1: 1.1024999618530273 	tau_2: 1.1024999618530273
# Train Epoch: 2 	Model: 5 	Training Loss: 753.8703071289062 	Temperature Strategy: exp_decrease 	tau_1: 0.9800999760627747 	tau_2: 0.9800999760627747
# Train Epoch: 2 	Model: 6 	Training Loss: 753.072493326823 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 2 	Model: 7 	Training Loss: 479.2926061197917 	Temperature Strategy: linear_increase 	tau_1: 3.0 	tau_2: 3.0
# Train Epoch: 2 	Model: 8 	Training Loss: 665.0869830729167 	Temperature Strategy: linear_decrease 	tau_1: 0.9800000190734863 	tau_2: 0.9800000190734863
# Train Epoch: 2 	Model: 9 	Training Loss: 739.4129763997396 	Temperature Strategy: exp_increase 	tau_1: 1.1024999618530273 	tau_2: 1.1024999618530273
# Best model saved with index: 7 and loss: 479.2926061197917
# Epoch: 2 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 3.0 	Best tau_2: 3.0
# Train Epoch: 3 	Model: 0 	Training Loss: 1068.649647623698 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 3 	Model: 1 	Training Loss: 654.7176284179687 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 3 	Model: 2 	Training Loss: 445.9654631347656 	Temperature Strategy: linear_increase 	tau_1: 4.0 	tau_2: 4.0
# Train Epoch: 3 	Model: 3 	Training Loss: 624.1886461588541 	Temperature Strategy: linear_decrease 	tau_1: 0.9700000286102295 	tau_2: 0.9700000286102295
# Train Epoch: 3 	Model: 4 	Training Loss: 603.0871178385416 	Temperature Strategy: exp_increase 	tau_1: 1.1576249599456787 	tau_2: 1.1576249599456787
# Train Epoch: 3 	Model: 5 	Training Loss: 743.9757163085937 	Temperature Strategy: exp_decrease 	tau_1: 0.9702990055084229 	tau_2: 0.9702990055084229
# Train Epoch: 3 	Model: 6 	Training Loss: 742.0528308919271 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 3 	Model: 7 	Training Loss: 443.4226884765625 	Temperature Strategy: linear_increase 	tau_1: 4.0 	tau_2: 4.0
# Train Epoch: 3 	Model: 8 	Training Loss: 649.4211471354166 	Temperature Strategy: linear_decrease 	tau_1: 0.9700000286102295 	tau_2: 0.9700000286102295
# Train Epoch: 3 	Model: 9 	Training Loss: 722.4316878255208 	Temperature Strategy: exp_increase 	tau_1: 1.1576249599456787 	tau_2: 1.1576249599456787
# Best model saved with index: 7 and loss: 443.4226884765625
# Epoch: 3 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1:
	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 8 	Model: 7 	Training Loss: 408.4188825683594 	Temperature Strategy: linear_increase 	tau_1: 9.0 	tau_2: 9.0
# Train Epoch: 8 	Model: 8 	Training Loss: 611.2812101236979 	Temperature Strategy: linear_decrease 	tau_1: 0.9200000166893005 	tau_2: 0.9200000166893005
# Train Epoch: 8 	Model: 9 	Training Loss: 661.1815802408854 	Temperature Strategy: exp_increase 	tau_1: 1.477455496788025 	tau_2: 1.477455496788025
# Best model saved with index: 7 and loss: 408.4188825683594
# Epoch: 8 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 9.0 	Best tau_2: 9.0
# Train Epoch: 9 	Model: 0 	Training Loss: 1068.4889819335938 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 9 	Model: 1 	Training Loss: 589.6666889648437 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 9 	Model: 2 	Training Loss: 406.9334632161458 	Temperature Strategy: linear_increase 	tau_1: 10.0 	tau_2: 10.0
# Train Epoch: 9 	Model: 3 	Training Loss: 594.1082957356771 	Temperature Strategy: linear_decrease 	tau_1: 0.9100000262260437 	tau_2: 0.9100000262260437
# Train Epoch: 9 	Model: 4 	Training Loss: 501.79179557291667 	Temperature Strategy: exp_increase 	tau_1: 1.551328182220459 	tau_2: 1.551328182220459
# Train Epoch: 9 	Model: 5 	Training Loss: 714.143373046875 	Temperature Strategy: exp_decrease 	tau_1: 0.9135172367095947 	tau_2: 0.9135172367095947
# Train Epoch: 9 	Model: 6 	Training Loss: 704.4851717122395 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 9 	Model: 7 	Training Loss: 406.3015098470052 	Temperature Strategy: linear_increase 	tau_1: 10.0 	tau_2: 10.0
# Train Epoch: 9 	Model: 8 	Training Loss: 606.4715056966146 	Temperature Strategy: linear_decrease 	tau_1: 0.9100000262260437 	tau_2: 0.9100000262260437
# Train Epoch: 9 	Model: 9 	Training Loss: 651.06287890625 	Temperature Strategy: exp_increase 	tau_1: 1.551328182220459 	tau_2: 1.551328182220459
# Best model saved with index: 7 and loss: 406.3015098470052
# Epoch: 9 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 10.0 	Best tau_2: 10.0
# Train Epoch: 10 	Model: 0 	Training Loss: 1068.432056640625 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 10 	Model: 1 	Training Loss: 584.0473294270834 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 10 	Model: 2 	Training Loss: 405.3182321777344 	Temperature Strategy: linear_increase 	tau_1: 11.0 	tau_2: 11.0
# Train Epoch: 10 	Model: 3 	Training Loss: 591.7422679036458 	Temperature Strategy: linear_decrease 	tau_1: 0.8999999761581421 	tau_2: 0.8999999761581421
# Train Epoch: 10 	Model: 4 	Training Loss: 489.05630444335935 	Temperature Strategy: exp_increase 	tau_1: 1.628894567489624 	tau_2: 1.628894567489624
# Train Epoch: 10 	Model: 5 	Training Loss: 711.3218181966146 	Temperature Strategy: exp_decrease 	tau_1: 0.904382050037384 	tau_2: 0.904382050037384
# Train Epoch: 10 	Model: 6 	Training Loss: 700.5813810221354 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 10 	Model: 7 	Training Loss: 404.6339833170573 	Temperature Strategy: linear_increase 	tau_1: 11.0 	tau_2: 11.0
# Train Epoch: 10 	Model: 8 	Training Loss: 602.9078216145833 	Temperature Strategy: linear_decrease 	tau_1: 0.8999999761581421 	tau_2: 0.8999999761581421
# Train Epoch: 10 	Model: 9 	Training Loss: 641.0851790364584 	Temperature Strategy: exp_increase 	tau_1: 1.628894567489624 	tau_2: 1.628894567489624
# Best model saved with index: 7 and loss: 404.6339833170573
# Epoch: 10 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 11.0 	Best tau_2: 11.0
# Train Epoch: 11 	Model: 0 	Training Loss: 1068.3349025065104 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 11 	Model: 1 	Training Loss: 578.8958396809896 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 11 	Model: 2 	Training Loss: 403.65923885091144 	Temperature Strategy: linear_increase 	tau_1: 12.0 	tau_2: 12.0
# Train Epoch: 11 	Model: 3 	Training Loss: 589.0962739257812 	Temperature Strategy: linear_decrease 	tau_1: 0.8899999856948853 	tau_2: 0.8899999856948853
# Train Epoch: 11 	Model: 4 	Training Loss: 477.73483626302084 	Temperature Strategy: exp_increase 	tau_1: 1.7103393077850342 	tau_2: 1.7103393077850342
# Train Epoch: 11 	Model: 5 	Training Loss: 709.3826555989583 	Temperature Strategy: exp_decrease 	tau_1: 0.895338237285614 	tau_2: 0.895338237285614
# Train Epoch: 11 	Model: 6 	Training Loss: 697.4098349609375 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 11 	Model: 7 	Training Loss: 403.30747835286456 	Temperature Strategy: linear_increase 	tau_1: 12.0 	tau_2: 12.0
# Train Epoch: 11 	Model: 8 	Training Loss: 600.2359674479167 	Temperature Strategy: linear_decrease 	tau_1: 0.8899999856948853 	tau_2: 0.8899999856948853
# Train Epoch: 11 	Model: 9 	Training Loss: 632.6707721354167 	Temperature Strategy: exp_increase 	tau_1: 1.7103393077850342 	tau_2: 1.7103393077850342
# Best model saved with index: 7 and loss: 403.30747835286456
# Epoch: 11 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 12.0 	Best tau_2: 12.0
# Train Epoch: 12 	Model: 0 	Training Loss: 1068.2611599934896 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 12 	Model: 1 	Training Loss: 574.8683364257812 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 12 	Model: 2 	Training Loss: 402.5587588704427 	Temperature Strategy: linear_increase 	tau_1: 13.0 	tau_2: 13.0
# Train Epoch: 12 	Model: 3 	Training Loss: 586.7412156575521 	Temperature Strategy: linear_decrease 	tau_1: 0.8799999952316284 	tau_2: 0.8799999952316284
# Train Epoch: 12 	Model: 4 	Training Loss: 467.75259334309897 	Temperature Strategy: exp_increase 	tau_1: 1.7958563566207886 	tau_2: 1.7958563566207886
# Train Epoch: 12 	Model: 5 	Training Loss: 707.1393637695312 	Temperature Strategy: exp_decrease 	tau_1: 0.8863848447799683 	tau_2: 0.8863848447799683
# Train Epoch: 12 	Model: 6 	Training Loss: 694.2618185221354 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 12 	Model: 7 	Training Loss: 402.06691105143227 	Temperature Strategy: linear_increase 	tau_1: 13.0 	tau_2: 13.0
# Train Epoch: 12 	Model: 8 	Training Loss: 597.2915690104167 	Temperature Strategy: linear_decrease 	tau_1: 0.8799999952316284 	tau_2: 0.8799999952316284
# Train Epoch: 12 	Model: 9 	Training Loss: 624.925616373698 	Temperature Strategy: exp_increase 	tau_1: 1.7958563566207886 	tau_2: 1.7958563566207886
# Best model saved with index: 7 and loss: 402.06691105143227
# Epoch: 12 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 13.0 	Best tau_2: 13.0
# Train Epoch: 13 	Model: 0 	Training Loss: 1068.4373971354166 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 13 	Model: 1 	Training Loss: 569.9666577148438 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 13 	Model: 2 	Training Loss: 401.57816577148435 	Temperature Strategy: linear_increase 	tau_1: 14.0 	tau_2: 14.0
# Train Epoch: 13 	Model: 3 	Training Loss: 585.2621528320312 	Temperature Strategy: linear_decrease 	tau_1: 0.8700000047683716 	tau_2: 0.8700000047683716
# Train Epoch: 13 	Model: 4 	Training Loss: 458.4568172200521 	Temperature Strategy: exp_increase 	tau_1: 1.8856490850448608 	tau_2: 1.8856490850448608
# Train Epoch: 13 	Model: 5 	Training Loss: 705.3708748372396 	Temperature Strategy: exp_decrease 	tau_1: 0.8775210380554199 	tau_2: 0.8775210380554199
# Train Epoch: 13 	Model: 6 	Training Loss: 691.4577698567708 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 13 	Model: 7 	Training Loss: 401.04399739583334 	Temperature Strategy: linear_increase 	tau_1: 14.0 	tau_2: 14.0
# Train Epoch: 13 	Model: 8 	Training Loss: 595.0020159505208 	Temperature Strategy: linear_decrease 	tau_1: 0.8700000047683716 	tau_2: 0.8700000047683716
# Train Epoch: 13 	Model: 9 	Training Loss: 618.1789786783854 	Temperature Strategy: exp_increase 	tau_1: 1.8856490850448608 	tau_2: 1.8856490850448608
# Best model saved with index: 7 and loss: 401.04399739583334
# Epoch: 13 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 14.0 	Best tau_2: 14.0
# Train Epoch: 14 	Model: 0 	Training Loss: 1068.1953092447916 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 14 	Model: 1 	Training Loss: 566.1952875976563 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 14 	Model: 2 	Training Loss: 400.6401940917969 	Temperature Strategy: linear_increase 	tau_1: 15.0 	tau_2: 15.0
# Train Epoch: 14 	Model: 3 	Training Loss: 583.4085022786459 	Temperature Strategy: linear_decrease 	tau_1: 0.8600000143051147 	tau_2: 0.8600000143051147
# Train Epoch: 14 	Model: 4 	Training Loss: 450.68280623372397 	Temperature Strategy: exp_increase 	tau_1: 1.9799315929412842 	tau_2: 1.9799315929412842
# Train Epoch: 14 	Model: 5 	Training Loss: 704.1239894205729 	Temperature Strategy: exp_decrease 	tau_1: 0.8687458038330078 	tau_2: 0.8687458038330078
# Train Epoch: 14 	Model: 6 	Training Loss: 689.47528515625 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 14 	Model: 7 	Training Loss: 400.2222232259115 	Temperature Strategy: linear_increase 	tau_1: 15.0 	tau_2: 15.0
# Train Epoch: 14 	Model: 8 	Training Loss: 592.7360489908854 	Temperature Strategy: linear_decrease 	tau_1: 0.8600000143051147 	tau_2: 0.8600000143051147
# Train Epoch: 14 	Model: 9 	Training Loss: 611.7805903320312 	Temperature Strategy: exp_increase 	tau_1: 1.9799315929412842 	tau_2: 1.9799315929412842
# Best model saved with index: 7 and loss: 400.2222232259115
# Epoch: 14 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 15.0 	Best tau_2: 15.0
# Train Epoch: 15 	Model: 0 	Training Loss: 1068.2424728190103 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 15 	Model: 1 	Training Loss: 562.8985911458333 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch:
	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 19 	Model: 7 	Training Loss: 396.6413015950521 	Temperature Strategy: linear_increase 	tau_1: 20.0 	tau_2: 20.0
# Train Epoch: 19 	Model: 8 	Training Loss: 586.0319261067708 	Temperature Strategy: linear_decrease 	tau_1: 0.8100000023841858 	tau_2: 0.8100000023841858
# Train Epoch: 19 	Model: 9 	Training Loss: 589.4891448567708 	Temperature Strategy: exp_increase 	tau_1: 2.5269501209259033 	tau_2: 2.5269501209259033
# Best model saved with index: 7 and loss: 396.6413015950521
# Epoch: 19 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 20.0 	Best tau_2: 20.0
# Train Epoch: 20 	Model: 0 	Training Loss: 1068.2145727539062 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 20 	Model: 1 	Training Loss: 549.3928829752604 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 20 	Model: 2 	Training Loss: 396.3778186035156 	Temperature Strategy: linear_increase 	tau_1: 21.0 	tau_2: 21.0
# Train Epoch: 20 	Model: 3 	Training Loss: 578.14682421875 	Temperature Strategy: linear_decrease 	tau_1: 0.800000011920929 	tau_2: 0.800000011920929
# Train Epoch: 20 	Model: 4 	Training Loss: 419.9845579427083 	Temperature Strategy: exp_increase 	tau_1: 2.6532976627349854 	tau_2: 2.6532976627349854
# Train Epoch: 20 	Model: 5 	Training Loss: 699.4450999348958 	Temperature Strategy: exp_decrease 	tau_1: 0.81790691614151 	tau_2: 0.81790691614151
# Train Epoch: 20 	Model: 6 	Training Loss: 678.1128671875 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 20 	Model: 7 	Training Loss: 396.1430441080729 	Temperature Strategy: linear_increase 	tau_1: 21.0 	tau_2: 21.0
# Train Epoch: 20 	Model: 8 	Training Loss: 585.5189186197916 	Temperature Strategy: linear_decrease 	tau_1: 0.800000011920929 	tau_2: 0.800000011920929
# Train Epoch: 20 	Model: 9 	Training Loss: 586.5328927408855 	Temperature Strategy: exp_increase 	tau_1: 2.6532976627349854 	tau_2: 2.6532976627349854
# Best model saved with index: 7 and loss: 396.1430441080729
# Epoch: 20 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 21.0 	Best tau_2: 21.0
# Train Epoch: 21 	Model: 0 	Training Loss: 1068.1145615234375 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 21 	Model: 1 	Training Loss: 546.16198828125 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 21 	Model: 2 	Training Loss: 396.013109375 	Temperature Strategy: linear_increase 	tau_1: 22.0 	tau_2: 22.0
# Train Epoch: 21 	Model: 3 	Training Loss: 578.0862859700521 	Temperature Strategy: linear_decrease 	tau_1: 0.7900000214576721 	tau_2: 0.7900000214576721
# Train Epoch: 21 	Model: 4 	Training Loss: 416.84539900716146 	Temperature Strategy: exp_increase 	tau_1: 2.7859625816345215 	tau_2: 2.7859625816345215
# Train Epoch: 21 	Model: 5 	Training Loss: 698.9460120442708 	Temperature Strategy: exp_decrease 	tau_1: 0.8097278475761414 	tau_2: 0.8097278475761414
# Train Epoch: 21 	Model: 6 	Training Loss: 676.9494389648437 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 21 	Model: 7 	Training Loss: 395.5786805013021 	Temperature Strategy: linear_increase 	tau_1: 22.0 	tau_2: 22.0
# Train Epoch: 21 	Model: 8 	Training Loss: 585.0164978841145 	Temperature Strategy: linear_decrease 	tau_1: 0.7900000214576721 	tau_2: 0.7900000214576721
# Train Epoch: 21 	Model: 9 	Training Loss: 583.440623046875 	Temperature Strategy: exp_increase 	tau_1: 2.7859625816345215 	tau_2: 2.7859625816345215
# Best model saved with index: 7 and loss: 395.5786805013021
# Epoch: 21 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1:
	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 24 	Model: 2 	Training Loss: 394.80611873372396 	Temperature Strategy: linear_increase 	tau_1: 25.0 	tau_2: 25.0
# Train Epoch: 24 	Model: 3 	Training Loss: 577.6190870768229 	Temperature Strategy: linear_decrease 	tau_1: 0.7599999904632568 	tau_2: 0.7599999904632568
# Train Epoch: 24 	Model: 4 	Training Loss: 409.4669473470052 	Temperature Strategy: exp_increase 	tau_1: 3.225100040435791 	tau_2: 3.225100040435791
# Train Epoch: 24 	Model: 5 	Training Loss: 697.6959842122396 	Temperature Strategy: exp_decrease 	tau_1: 0.7856781482696533 	tau_2: 0.7856781482696533
# Train Epoch: 24 	Model: 6 	Training Loss: 672.2337255859375 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 24 	Model: 7 	Training Loss: 394.3486588541667 	Temperature Strategy: linear_increase 	tau_1: 25.0 	tau_2: 25.0
# Train Epoch: 24 	Model: 8 	Training Loss: 584.1085522460937 	Temperature Strategy: linear_decrease 	tau_1: 0.7599999904632568 	tau_2: 0.7599999904632568
# Train Epoch: 24 	Model: 9 	Training Loss: 576.5181798502604 	Temperature Strategy: exp_increase 	tau_1: 3.225100040435791 	tau_2: 3.225100040435791
# Best model saved with index: 7 and loss: 394.3486588541667
# Epoch: 24 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 25.0 	Best tau_2: 25.0
# Train Epoch: 25 	Model: 0 	Training Loss: 1068.000102376302 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 25 	Model: 1 	Training Loss: 538.9878795572916 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 25 	Model: 2 	Training Loss: 393.8956979980469 	Temperature Strategy: linear_increase 	tau_1: 26.0 	tau_2: 26.0
# Train Epoch: 25 	Model: 3 	Training Loss: 577.2813011067708 	Temperature Strategy: linear_decrease 	tau_1: 0.75 	tau_2: 0.75
# Train Epoch: 25 	Model: 4 	Training Loss: 407.6321814778646 	Temperature Strategy: exp_increase 	tau_1: 3.386354923248291 	tau_2: 3.386354923248291
# Train Epoch: 25 	Model: 5 	Training Loss: 697.5751883138021 	Temperature Strategy: exp_decrease 	tau_1: 0.7778213620185852 	tau_2: 0.7778213620185852
# Train Epoch: 25 	Model: 6 	Training Loss: 671.1868471679687 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 25 	Model: 7 	Training Loss: 393.7849072265625 	Temperature Strategy: linear_increase 	tau_1: 26.0 	tau_2: 26.0
# Train Epoch: 25 	Model: 8 	Training Loss: 583.9578530273437 	Temperature Strategy: linear_decrease 	tau_1: 0.75 	tau_2: 0.75
# Train Epoch: 25 	Model: 9 	Training Loss: 574.791358561198 	Temperature Strategy: exp_increase 	tau_1: 3.386354923248291 	tau_2: 3.386354923248291
# Best model saved with index: 7 and loss: 393.7849072265625
# Epoch: 25 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 26.0 	Best tau_2: 26.0
# Train Epoch: 26 	Model: 0 	Training Loss: 1068.057436360677 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 26 	Model: 1 	Training Loss: 537.2712163085937 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 26 	Model: 2 	Training Loss: 393.6909893391927 	Temperature Strategy: linear_increase 	tau_1: 27.0 	tau_2: 27.0
# Train Epoch: 26 	Model: 3 	Training Loss: 577.1091647135416 	Temperature Strategy: linear_decrease 	tau_1: 0.7400000095367432 	tau_2: 0.7400000095367432
# Train Epoch: 26 	Model: 4 	Training Loss: 405.6252448730469 	Temperature Strategy: exp_increase 	tau_1: 3.5556726455688477 	tau_2: 3.5556726455688477
# Train Epoch: 26 	Model: 5 	Training Loss: 697.5558875325521 	Temperature Strategy: exp_decrease 	tau_1: 0.770043134689331 	tau_2: 0.770043134689331
# Train Epoch: 26 	Model: 6 	Training Loss: 669.9375035807292 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 26 	Model: 7 	Training Loss: 393.52242732747396 	Temperature Strategy: linear_increase 	tau_1: 27.0 	tau_2: 27.0
# Train Epoch: 26 	Model: 8 	Training Loss: 583.9340092773438 	Temperature Strategy: linear_decrease 	tau_1: 0.7400000095367432 	tau_2: 0.7400000095367432
# Train Epoch: 26 	Model: 9 	Training Loss: 573.1171567382812 	Temperature Strategy: exp_increase 	tau_1: 3.5556726455688477 	tau_2: 3.5556726455688477
# Best model saved with index: 7 and loss: 393.52242732747396
# Epoch: 26 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 27.0 	Best tau_2: 27.0
# Train Epoch: 27 	Model: 0 	Training Loss: 1068.1098802083334 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 27 	Model: 1 	Training Loss: 535.237455078125 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 27 	Model: 2 	Training Loss: 393.32681640625 	Temperature Strategy: linear_increase 	tau_1: 28.0 	tau_2: 28.0
# Train Epoch: 27 	Model: 3 	Training Loss: 578.0207622070312 	Temperature Strategy: linear_decrease 	tau_1: 0.7300000190734863 	tau_2: 0.7300000190734863
# Train Epoch: 27 	Model: 4 	Training Loss: 404.06041389973956 	Temperature Strategy: exp_increase 	tau_1: 3.7334563732147217 	tau_2: 3.7334563732147217
# Train Epoch: 27 	Model: 5 	Training Loss: 697.6725833333334 	Temperature Strategy: exp_decrease 	tau_1: 0.7623426914215088 	tau_2: 0.7623426914215088
# Train Epoch: 27 	Model: 6 	Training Loss: 667.9526544596354 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 27 	Model: 7 	Training Loss: 393.3011301269531 	Temperature Strategy: linear_increase 	tau_1: 28.0 	tau_2: 28.0
# Train Epoch: 27 	Model: 8 	Training Loss: 584.753784342448 	Temperature Strategy: linear_decrease 	tau_1: 0.7300000190734863 	tau_2: 0.7300000190734863
# Train Epoch: 27 	Model: 9 	Training Loss: 571.6576145833334 	Temperature Strategy: exp_increase 	tau_1: 3.7334563732147217 	tau_2: 3.7334563732147217
# Best model saved with index: 7 and loss: 393.3011301269531
# Epoch: 27 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 28.0 	Best tau_2: 28.0
# Train Epoch: 28 	Model: 0 	Training Loss: 1068.0479765625 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 28 	Model: 1 	Training Loss: 533.4174497070312 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 28 	Model: 2 	Training Loss: 392.95920255533855 	Temperature Strategy: linear_increase 	tau_1: 29.0 	tau_2: 29.0
# Train Epoch: 28 	Model: 3 	Training Loss: 578.0157430013021 	Temperature Strategy: linear_decrease 	tau_1: 0.7200000286102295 	tau_2: 0.7200000286102295
# Train Epoch: 28 	Model: 4 	Training Loss: 402.7886348470052 	Temperature Strategy: exp_increase 	tau_1: 3.9201290607452393 	tau_2: 3.9201290607452393
# Train Epoch: 28 	Model: 5 	Training Loss: 697.2366984049479 	Temperature Strategy: exp_decrease 	tau_1: 0.7547193169593811 	tau_2: 0.7547193169593811
# Train Epoch: 28 	Model: 6 	Training Loss: 666.9907516276041 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 28 	Model: 7 	Training Loss: 392.82529736328127 	Temperature Strategy: linear_increase 	tau_1: 29.0 	tau_2: 29.0
# Train Epoch: 28 	Model: 8 	Training Loss: 585.1581943359375 	Temperature Strategy: linear_decrease 	tau_1: 0.7200000286102295 	tau_2: 0.7200000286102295
# Train Epoch: 28 	Model: 9 	Training Loss: 570.2647736002605 	Temperature Strategy: exp_increase 	tau_1: 3.9201290607452393 	tau_2: 3.9201290607452393
# Best model saved with index: 7 and loss: 392.82529736328127
# Epoch: 28 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 29.0 	Best tau_2: 29.0
# Train Epoch: 29 	Model: 0 	Training Loss: 1068.076131998698 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 29 	Model: 1 	Training Loss: 531.2716740722656 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 29 	Model: 2 	Training Loss: 392.61148461914064 	Temperature Strategy: linear_increase 	tau_1: 30.0 	tau_2: 30.0
# Train Epoch: 29 	Model: 3 	Training Loss: 578.4618203125 	Temperature Strategy: linear_decrease 	tau_1: 0.7099999785423279 	tau_2: 0.7099999785423279
# Train Epoch: 29 	Model: 4 	Training Loss: 401.4755137532552 	Temperature Strategy: exp_increase 	tau_1: 4.116135597229004 	tau_2: 4.116135597229004
# Train Epoch: 29 	Model: 5 	Training Loss: 696.976392578125 	Temperature Strategy: exp_decrease 	tau_1: 0.7471721172332764 	tau_2: 0.7471721172332764
# Train Epoch: 29 	Model: 6 	Training Loss: 665.815001953125 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 29 	Model: 7 	Training Loss: 392.60428751627603 	Temperature Strategy: linear_increase 	tau_1: 30.0 	tau_2: 30.0
# Train Epoch: 29 	Model: 8 	Training Loss: 584.9665716145834 	Temperature Strategy: linear_decrease 	tau_1: 0.7099999785423279 	tau_2: 0.7099999785423279
# Train Epoch: 29 	Model: 9 	Training Loss: 569.098744140625 	Temperature Strategy: exp_increase 	tau_1: 4.116135597229004 	tau_2: 4.116135597229004
# Best model saved with index: 7 and loss: 392.60428751627603
# Epoch: 29 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 30.0 	Best tau_2: 30.0
# Train Epoch: 30 	Model: 0 	Training Loss: 1067.9671481119792 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 30 	Model: 1 	Training Loss: 530.1280975748698 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 30 	Model: 2 	Training Loss: 392.442050374349 	Temperature Strategy: linear_increase 	tau_1: 31.0 	tau_2: 31.0
# Train Epoch: 30 	Model: 3 	Training Loss: 579.1603121744791 	Temperature Strategy: linear_decrease 	tau_1: 0.699999988079071 	tau_2: 0.699999988079071
# Train Epoch: 30 	Model: 4 	Training Loss: 400.4013729654948 	Temperature Strategy: exp_increase 	tau_1: 4.321942329406738 	tau_2: 4.321942329406738
# Train Epoch: 30 	Model: 5 	Training Loss: 697.3482280273438 	Temperature Strategy: exp_decrease 	tau_1: 0.7397003769874573 	tau_2: 0.7397003769874573
# Train Epoch: 30 	Model: 6 	Training Loss: 664.6659090169271 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 30 	Model: 7 	Training Loss: 392.3042755533854 	Temperature Strategy: linear_increase 	tau_1: 31.0 	tau_2: 31.0
# Train Epoch: 30 	Model: 8 	Training Loss: 585.6572962239584 	Temperature Strategy: linear_decrease 	tau_1: 0.699999988079071 	tau_2: 0.699999988079071
# Train Epoch: 30 	Model: 9 	Training Loss: 568.1619345703125 	Temperature Strategy: exp_increase 	tau_1: 4.321942329406738 	tau_2: 4.321942329406738
# Best model saved with index: 7 and loss: 392.3042755533854
# Epoch: 30 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 31.0 	Best tau_2: 31.0
# Train Epoch: 31 	Model: 0 	Training Loss: 1068.0391966145833 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch:
	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 111 	Model: 4 	Training Loss: 386.93629923502607 	Temperature Strategy: exp_increase 	tau_1: 224.91177368164062 	tau_2: 224.91177368164062
# Train Epoch: 111 	Model: 5 	Training Loss: 700.3409049479167 	Temperature Strategy: exp_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 111 	Model: 6 	Training Loss: 624.6589894205729 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 111 	Model: 7 	Training Loss: 385.3382683105469 	Temperature Strategy: linear_increase 	tau_1: 112.0 	tau_2: 112.0
# Train Epoch: 111 	Model: 8 	Training Loss: 589.4037833658854 	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 111 	Model: 9 	Training Loss: 554.630658203125 	Temperature Strategy: exp_increase 	tau_1: 224.91177368164062 	tau_2: 224.91177368164062
# Epoch: 111 	Best Model Index: 2 	Best Temperature Strategy: linear_increase 	Best tau_1: 112.0 	Best tau_2: 112.0
# Train Epoch: 112 	Model: 0 	Training Loss: 1067.908843424479 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 112 	Model: 1 	Training Loss: 476.72443782552085 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 112 	Model: 2 	Training Loss: 385.3560558268229 	Temperature Strategy: linear_increase 	tau_1: 113.0 	tau_2: 113.0
# Train Epoch: 112 	Model: 3 	Training Loss: 585.8767895507813 	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 112 	Model: 4 	Training Loss: 386.1298740234375 	Temperature Strategy: exp_increase 	tau_1: 236.15736389160156 	tau_2: 236.15736389160156
# Train Epoch: 112 	Model: 5 	Training Loss: 700.7133759765625 	Temperature Strategy: exp_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 112 	Model: 6 	Training Loss: 624.9553292643229 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 112 	Model: 7 	Training Loss: 385.297534749349 	Temperature Strategy: linear_increase 	tau_1: 113.0 	tau_2: 113.0
# Train Epoch: 112 	Model: 8 	Training Loss: 588.6978045247396 	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 112 	Model: 9 	Training Loss: 554.8082171223958 	Temperature Strategy: exp_increase 	tau_1: 236.15736389160156 	tau_2: 236.15736389160156
# Epoch: 112 	Best Model Index: 7 	Best Temperature Strategy: linear_increase 	Best tau_1: 113.0 	Best tau_2: 113.0
# Train Epoch: 113 	Model: 0 	Training Loss: 1067.8082789713542 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 113 	Model: 1 	Training Loss: 476.41483260091144 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 113 	Model: 2 	Training Loss: 385.23120434570313 	Temperature Strategy: linear_increase 	tau_1: 114.0 	tau_2: 114.0
# Train Epoch: 113 	Model: 3 	Training Loss: 585.8141875 	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 113 	Model: 4 	Training Loss: 386.7971068522135 	Temperature Strategy: exp_increase 	tau_1: 247.96524047851562 	tau_2: 247.96524047851562
# Train Epoch: 113 	Model: 5 	Training Loss: 700.364162109375 	Temperature Strategy: exp_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 113 	Model: 6 	Training Loss: 624.3361077473959 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 113 	Model: 7 	Training Loss: 385.2419523111979 	Temperature Strategy: linear_increase 	tau_1: 114.0 	tau_2: 114.0
# Train Epoch: 113 	Model: 8 	Training Loss: 588.9144529622396 	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch: 113 	Model: 9 	Training Loss: 554.6792093098958 	Temperature Strategy: exp_increase 	tau_1: 247.96524047851562 	tau_2: 247.96524047851562
# Epoch: 113 	Best Model Index: 2 	Best Temperature Strategy: linear_increase 	Best tau_1: 114.0 	Best tau_2: 114.0
# Train Epoch: 114 	Model: 0 	Training Loss: 1067.8788204752605 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 114 	Model: 1 	Training Loss: 475.8027377115885 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 114 	Model: 2 	Training Loss: 385.3365944010417 	Temperature Strategy: linear_increase 	tau_1: 115.0 	tau_2: 115.0
# Train Epoch: 114 	Model: 3 	Training Loss: 585.4220795898437 	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# Train Epoch:
	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 117 	Model: 1 	Training Loss: 474.5502320963542 	Temperature Strategy: fixed 	tau_1: 1.0 	tau_2: 1.0
# Train Epoch: 117 	Model: 2 	Training Loss: 385.17339119466146 	Temperature Strategy: linear_increase 	tau_1: 118.0 	tau_2: 118.0
# Train Epoch: 117 	Model: 3 	Training Loss: 585.566734375 	Temperature Strategy: linear_decrease 	tau_1: 0.5 	tau_2: 0.5
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 243
#     241     model.tau_2 = nn.Parameter(torch.tensor(max(initial_taus[i] - epoch * lin_decrease, tau_min)), requires_grad=True)
#     242 elif temp_strategy == 'exp_increase':
# --> 243     model.tau_1 = nn.Parameter(torch.tensor(min(initial_taus[i] * (exp_increase ** epoch), tau_max)), requires_grad=True)
#     244     model.tau_2 = nn.Parameter(torch.tensor(min(initial_taus[i] * (exp_increase ** epoch), tau_max)), requires_grad=True)
#     245 elif temp_strategy == 'exp_decrease':
#
# File ~\.conda\envs\old13\lib\site-packages\torch\nn\parameter.py:40, in Parameter.__new__(cls, data, requires_grad)
#      36     data = torch.empty(0)
#      37 if type(data) is torch.Tensor or type(data) is Parameter:
#      38     # For ease of BC maintenance, keep this path for standard Tensor.
#      39     # Eventually (tm), we should change the behavior for standard Tensor to match.
# ---> 40     return torch.Tensor._make_subclass(cls, data, requires_grad)
#      42 # Path for custom tensors: set a flag on the instance to indicate parameter-ness.
#      43 t = data.detach().requires_grad_(requires_grad)
#
# RuntimeError: Only Tensors of floating point and complex dtype can require gradients

# %%
# Output the best tau for each epoch
for epoch, (tau_1, tau_2) in enumerate(zip(best_tau_per_epoch_1, best_tau_per_epoch_2)):
    print(f"Epoch: {epoch}, Best Tau 1: {tau_1}, Best Tau 2: {tau_2}")

# Plot the best_tau_per_epoch
plt.figure(figsize=(12, 8))
plt.plot(range(117), best_tau_per_epoch_1, label='Best Tau 1 per Epoch')
plt.plot(range(117), best_tau_per_epoch_2, label='Best Tau 2 per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Tau values')
plt.title('Best Tau Values per Epoch')
plt.legend()
plt.show()
# Out:
# Epoch: 0, Best Tau 1: 1.0, Best Tau 2: 1.0
# Epoch: 1, Best Tau 1: 2.0, Best Tau 2: 2.0
# Epoch: 2, Best Tau 1: 3.0, Best Tau 2: 3.0
# Epoch: 3, Best Tau 1: 4.0, Best Tau 2: 4.0
# Epoch: 4, Best Tau 1: 5.0, Best Tau 2: 5.0
# Epoch: 5, Best Tau 1: 6.0, Best Tau 2: 6.0
# Epoch: 6, Best Tau 1: 7.0, Best Tau 2: 7.0
# Epoch: 7, Best Tau 1: 8.0, Best Tau 2: 8.0
# Epoch: 8, Best Tau 1: 9.0, Best Tau 2: 9.0
# Epoch: 9, Best Tau 1: 10.0, Best Tau 2: 10.0
# Epoch: 10, Best Tau 1: 11.0, Best Tau 2: 11.0
# Epoch: 11, Best Tau 1: 12.0, Best Tau 2: 12.0
# Epoch: 12, Best Tau 1: 13.0, Best Tau 2: 13.0
# Epoch: 13, Best Tau 1: 14.0, Best Tau 2: 14.0
# Epoch: 14, Best Tau 1: 15.0, Best Tau 2: 15.0
# Epoch: 15, Best Tau 1: 16.0, Best Tau 2: 16.0
# Epoch: 16, Best Tau 1: 17.0, Best Tau 2: 17.0
# Epoch: 17, Best Tau 1: 18.0, Best Tau 2: 18.0
# Epoch: 99, Best Tau 1: 125.23929595947266, Best Tau 2: 125.23929595947266
# Epoch: 100, Best Tau 1: 101.0, Best Tau 2: 101.0
# Epoch: 101, Best Tau 1: 138.07632446289062, Best Tau 2: 138.07632446289062
# Epoch: 102, Best Tau 1: 144.98013305664062, Best Tau 2: 144.98013305664062
# Epoch: 103, Best Tau 1: 104.0, Best Tau 2: 104.0
# Epoch: 104, Best Tau 1: 159.84060668945312, Best Tau 2: 159.84060668945312
# Epoch: 105, Best Tau 1: 106.0, Best Tau 2: 106.0
# Epoch: 106, Best Tau 1: 107.0, Best Tau 2: 107.0
# Epoch: 107, Best Tau 1: 108.0, Best Tau 2: 108.0
# Epoch: 108, Best Tau 1: 109.0, Best Tau 2: 109.0
# Epoch: 109, Best Tau 1: 110.0, Best Tau 2: 110.0
# Epoch: 110, Best Tau 1: 111.0, Best Tau 2: 111.0
# Epoch: 111, Best Tau 1: 112.0, Best Tau 2: 112.0
# Epoch: 112, Best Tau 1: 113.0, Best Tau 2: 113.0
# Epoch: 113, Best Tau 1: 114.0, Best Tau 2: 114.0
# Epoch: 114, Best Tau 1: 115.0, Best Tau 2: 115.0
# Epoch: 115, Best Tau 1: 116.0, Best Tau 2: 116.0
# Epoch: 116, Best Tau 1: 117.0, Best Tau 2: 117.0

# %%
# index 2 means the model 2 by using exponential increasing temperature strategy
best_model_path = r"F:\rPPGdata_4\MNIST\best_model_MNIST_parallel_desktop2070.pth"

torch.save(models[best_model_idx].state_dict(), best_model_path)
print(f'Best model saved with index: {best_model_idx}')
# Out:
# Best model saved with index: 2

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from skimage.metrics import structural_similarity as ssim
import numpy as np

# Define the transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
BATCH_SIZE = 128
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

# Remove digits 2 and 3 from the training dataset
train_dataset.data = train_dataset.data[(train_dataset.targets != 2) & (train_dataset.targets != 3)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets != 2) & (train_dataset.targets != 3)]

# Create new data loaders after removing digits 2 and 3
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

# Function to plot images
def plot_images(original_images, reconstructed_images, n=10):
    original_images = original_images.cpu().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Display original images
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstruction images
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Calculate MSE and SSIM for the entire test dataset
mse_losses = []
ssim_values = []

with torch.no_grad():
    for data, targets in test_loader:
        data = data.to(device)

        # Reconstruct the images
        recon_batch, _, _, _, _ = models[best_model_idx](data)

        # Calculate MSE loss
        mse_loss = F.mse_loss(recon_batch, data)
        mse_losses.append(mse_loss.item())

        # Calculate SSIM
        for i in range(data.size(0)):
            original = data[i].cpu().numpy().transpose(1, 2, 0).squeeze()
            reconstruction = recon_batch[i].cpu().numpy().transpose(1, 2, 0).squeeze()
            ssim_value = ssim(original, reconstruction, data_range=reconstruction.max() - reconstruction.min())
            ssim_values.append(ssim_value)

# Calculate average MSE and SSIM
avg_mse = np.mean(mse_losses)
avg_ssim = np.mean(ssim_values)

print(f'Average MSE: {avg_mse}')
print(f'Average SSIM: {avg_ssim}')

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Pass the images through the best model
recon_batch, _, _, _, _ = models[best_model_idx](data)

# Plot the original and reconstructed images
plot_images(data.cpu(), recon_batch.cpu())
# Out:
# Average MSE: 0.00048605072432893176
# Average SSIM: 0.9901349433529935

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
batch_size = 128

def get_latent_vectors(model, data):
    with torch.no_grad():
        _, _, _, _, z = model(data)
        return z


all_latent_vectors = []
all_labels = []


for data, labels in test_loader:
    data = data.to(device)
    latent_vectors = get_latent_vectors(models[best_model_idx], data).cpu().detach().numpy()
    all_latent_vectors.append(latent_vectors)
    all_labels.append(labels.numpy())

    if len(all_latent_vectors) * batch_size > 10000:
        break


all_latent_vectors = np.concatenate(all_latent_vectors, axis=0)
all_labels = np.concatenate(all_labels, axis=0)


tsne = TSNE(n_components=2, random_state=0)
all_latent_tsne = tsne.fit_transform(all_latent_vectors)


plt.figure(figsize=(10, 8))
plt.scatter(all_latent_tsne[:, 0], all_latent_tsne[:, 1], c=all_labels, cmap='tab10')
plt.colorbar()
plt.title('t-SNE of Latent Vectors')
plt.show()
# Out:
# C:\Users\zhouf\.conda\envs\old13\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\zhouf\.conda\envs\old13\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Results of my parallel GS-VAEs on MNIST reconstruction of unseen digits (2s and 3s)
def plot_images(original_images, reconstructed_images, n=10):
    original_images = original_images.cpu().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Display original images
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstruction images
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to filter out only the digits 2 and 3
def filter_2_and_3(data, target):
    mask = (target == 2) | (target == 3)
    return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Filter out only the digits 2 and 3
data, targets = filter_2_and_3(data, targets)

# Pass the images through the best model
recon_batch, _, _, _, _ = models[best_model_idx](data)

# Plot the original and reconstructed images
plot_images(data.cpu(), recon_batch.cpu())

# %%
# Test the models performance for reconstruction under high-intensity FGSM adversarial attacks
# The models were trained by the dataset without 2s and 3s
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Define the transform
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Adjust input image size to match the model's expected input size
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# FGSM attack function
def fgsm_attack(image, epsilon, data_grad):
    sign_data_grad = data_grad.sign()
    perturbed_image = image + epsilon * sign_data_grad
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    return perturbed_image

# Plot original images, FGSM attacked images, and reconstructed FGSM attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().detach().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display FGSM attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed FGSM attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to filter out only the digits 2 and 3
def filter_2_and_3(data, target):
    mask = (target == 2) | (target == 3)
    return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Filter out only the digits 2 and 3
data, targets = filter_2_and_3(data, targets)

# Set FGSM attack parameters
epsilon = 0.4  # Attack strength

# Need to calculate the gradient of the data
data.requires_grad = True

# Get model predictions on the original data
output, _, _, _, _ = models[best_model_idx](data)
loss = F.mse_loss(output, data)
models[best_model_idx].zero_grad()
loss.backward()

# Generate adversarial samples
data_grad = data.grad.data
perturbed_data = fgsm_attack(data, epsilon, data_grad)

# Reconstruct adversarial samples
recon_batch = models[best_model_idx](perturbed_data)[0]

# Plot original images, FGSM attacked images, and reconstructed FGSM attacked images
plot_images(data, perturbed_data, recon_batch)

# %%
# Test performance of reconstruction under FGSM attack by using our model
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# FGSM attack function
def fgsm_attack(data, epsilon, gradient):
    sign_data_grad = gradient.sign()
    perturbed_data = data + epsilon * sign_data_grad
    perturbed_data = torch.clamp(perturbed_data, 0, 1)
    return perturbed_data

# Plot original images, FGSM attacked images, and reconstructed FGSM attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().detach().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display FGSM attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed FGSM attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to filter out only the digits 2 and 3
def filter_2_and_3(data, target):
    mask = (target == 2) | (target == 3)
    return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Filter out only the digits 2 and 3
data, targets = filter_2_and_3(data, targets)

# Set FGSM attack parameters
epsilon = 0.1  # Attack strength

# Need to calculate the gradient of the data
data.requires_grad = True

# Get model predictions on the original data
output, _, _, _, _ = models[best_model_idx](data)
loss = F.binary_cross_entropy(output, data)
models[best_model_idx].zero_grad()
loss.backward()

# Generate adversarial samples
data_grad = data.grad.data
perturbed_data = fgsm_attack(data, epsilon, data_grad)

# Reconstruct adversarial samples
recon_batch, _, _, _, _ = models[best_model_idx](perturbed_data)

# Plot original images, FGSM attacked images, and reconstructed FGSM attacked images
plot_images(data.cpu().detach(), perturbed_data.cpu().detach(), recon_batch.cpu().detach())

# %%
# Test performance of reconstruction under FGSM attack by using our model
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# FGSM attack function
def fgsm_attack(data, epsilon, gradient):
    sign_data_grad = gradient.sign()
    perturbed_data = data + epsilon * sign_data_grad
    perturbed_data = torch.clamp(perturbed_data, 0, 1)
    return perturbed_data

# Plot original images, FGSM attacked images, and reconstructed FGSM attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().detach().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display FGSM attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed FGSM attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Define the transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

# Remove digits 2 and 3 from the training dataset
train_dataset.data = train_dataset.data[(train_dataset.targets != 2) & (train_dataset.targets != 3)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets != 2) & (train_dataset.targets != 3)]

# # Remove digits 2 and 3 from the test dataset
# test_dataset.data = test_dataset.data[(test_dataset.targets != 2) & (test_dataset.targets != 3)]
# test_dataset.targets = test_dataset.targets[(test_dataset.targets != 2) & (test_dataset.targets != 3)]

# Create new data loaders after removing digits 2 and 3
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

# # Function to filter out only the digits 2 and 3
# def filter_2_and_3(data, target):
#     mask = (target == 2) | (target == 3)
#     return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# # Filter out only the digits 2 and 3
# data, targets = filter_2_and_3(data, targets)

# Set FGSM attack parameters
epsilon = 0.1  # Attack strength

# Need to calculate the gradient of the data
data.requires_grad = True

# Get model predictions on the original data
output, _, _, _, _ = models[best_model_idx](data)
loss = F.binary_cross_entropy(output, data)
models[best_model_idx].zero_grad()
loss.backward()

# Generate adversarial samples
data_grad = data.grad.data
perturbed_data = fgsm_attack(data, epsilon, data_grad)

# Reconstruct adversarial samples
recon_batch, _, _, _, _ = models[best_model_idx](perturbed_data)

# Plot original images, FGSM attacked images, and reconstructed FGSM attacked images
plot_images(data.cpu().detach(), perturbed_data.cpu().detach(), recon_batch.cpu().detach())

# %%
# Test the models performance for reconstruction under high-intensity PGD adversarial attacks
# The models were trained by the dataset without 2s and 3s
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Define the transform
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Adjust input image size to match the model's expected input size
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# PGD attack function
def pgd_attack(model, images, epsilon, alpha, num_iter):
    images = images.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output, _, _, _, _ = model(images)
        loss = F.mse_loss(output, images)
        model.zero_grad()
        loss.backward()
        with torch.no_grad():
            perturbed_images = images + alpha * images.grad.sign()
            perturbed_images = torch.clamp(perturbed_images, 0, 1)
            perturbed_images = torch.max(torch.min(perturbed_images, images + epsilon), images - epsilon)
            images = perturbed_images.detach().requires_grad_(True)
    return images

# Plot original images, PGD attacked images, and reconstructed PGD attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().detach().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display PGD attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed PGD attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to filter out only the digits 2 and 3
def filter_2_and_3(data, target):
    mask = (target == 2) | (target == 3)
    return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Filter out only the digits 2 and 3
data, targets = filter_2_and_3(data, targets)

# Set PGD attack parameters
epsilon = 0.5  # Maximum perturbation
alpha = 0.01   # Step size, increased to make attack stronger
num_iter = 15  # Number of iterations

# Generate adversarial samples using PGD
perturbed_data = pgd_attack(models[best_model_idx], data, epsilon, alpha, num_iter)

# Reconstruct adversarial samples
recon_batch = models[best_model_idx](perturbed_data)[0]

# Plot original images, PGD attacked images, and reconstructed PGD attacked images
plot_images(data, perturbed_data, recon_batch)

# %%
# Test performance of reconstruction under PGD attack by using our model
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# PGD attack function
def pgd_attack(model, data, epsilon, alpha, num_iter):
    perturbed_data = data.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output, _, _, _, _ = model(perturbed_data)
        loss = F.binary_cross_entropy(output, data)
        model.zero_grad()
        loss.backward()
        with torch.no_grad():
            perturbed_data += alpha * perturbed_data.grad.sign()
            perturbed_data = torch.clamp(perturbed_data, 0, 1)
            perturbed_data = torch.max(torch.min(perturbed_data, data + epsilon), data - epsilon)
            perturbed_data = perturbed_data.detach().requires_grad_(True)
    return perturbed_data

# Plot original images, PGD attacked images, and reconstructed PGD attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display PGD attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed PGD attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to filter out only the digits 2 and 3
def filter_2_and_3(data, target):
    mask = (target == 2) | (target == 3)
    return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Filter out only the digits 2 and 3
data, targets = filter_2_and_3(data, targets)

# Set PGD attack parameters
epsilon = 0.1  # Maximum perturbation
alpha = 0.01   # Step size
num_iter = 20  # Number of iterations

# Generate adversarial samples using PGD
perturbed_data = pgd_attack(models[best_model_idx], data, epsilon, alpha, num_iter)

# Reconstruct adversarial samples
recon_batch, _, _, _, _ = models[best_model_idx](perturbed_data)

# Plot original images, PGD attacked images, and reconstructed PGD attacked images
plot_images(data.cpu(), perturbed_data.cpu(), recon_batch.cpu())

# %%
# Test performance of reconstruction under PGD attack by using our model
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# PGD attack function
def pgd_attack(model, data, epsilon, alpha, num_iter):
    perturbed_data = data.clone().detach().requires_grad_(True).to(device)
    for _ in range(num_iter):
        output, _, _, _, _ = model(perturbed_data)
        loss = F.binary_cross_entropy(output, data)
        model.zero_grad()
        loss.backward()
        with torch.no_grad():
            perturbed_data += alpha * perturbed_data.grad.sign()
            perturbed_data = torch.clamp(perturbed_data, 0, 1)
            perturbed_data = torch.max(torch.min(perturbed_data, data + epsilon), data - epsilon)
            perturbed_data = perturbed_data.detach().requires_grad_(True)
    return perturbed_data

# Plot original images, PGD attacked images, and reconstructed PGD attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display PGD attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed PGD attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Define the transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

# Remove digits 2 and 3 from the training dataset
train_dataset.data = train_dataset.data[(train_dataset.targets != 2) & (train_dataset.targets != 3)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets != 2) & (train_dataset.targets != 3)]

# # Remove digits 2 and 3 from the test dataset
# test_dataset.data = test_dataset.data[(test_dataset.targets != 2) & (test_dataset.targets != 3)]
# test_dataset.targets = test_dataset.targets[(test_dataset.targets != 2) & (test_dataset.targets != 3)]

# Create new data loaders after removing digits 2 and 3
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

# Function to filter out only the digits 2 and 3
# def filter_2_and_3(data, target):
#     mask = (target == 2) | (target == 3)
#     return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# # Filter out only the digits 2 and 3
# data, targets = filter_2_and_3(data, targets)

# Set PGD attack parameters
epsilon = 0.5  # Maximum perturbation
alpha = 0.01   # Step size
num_iter = 20  # Number of iterations

# Generate adversarial samples using PGD
perturbed_data = pgd_attack(models[best_model_idx], data, epsilon, alpha, num_iter)

# Reconstruct adversarial samples
recon_batch, _, _, _, _ = models[best_model_idx](perturbed_data)

# Plot original images, PGD attacked images, and reconstructed PGD attacked images
plot_images(data.cpu(), perturbed_data.cpu(), recon_batch.cpu())

# %%
# Test performance of reconstruction under Gaussian noise attack by using our model
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# Gaussian noise attack function
def gaussian_noise_attack(data, std):
    noise = torch.randn_like(data) * std
    perturbed_data = data + noise
    perturbed_data = torch.clamp(perturbed_data, 0, 1)
    return perturbed_data

# Plot original images, Gaussian noise attacked images, and reconstructed Gaussian noise attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display Gaussian noise attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed Gaussian noise attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to filter out only the digits 2 and 3
def filter_2_and_3(data, target):
    mask = (target == 2) | (target == 3)
    return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Filter out only the digits 2 and 3
data, targets = filter_2_and_3(data, targets)

# Set Gaussian noise attack parameters
std = 0.3  # Noise standard deviation

# Generate adversarial samples using Gaussian noise
perturbed_data = gaussian_noise_attack(data, std)

# Reconstruct adversarial samples
recon_batch, _, _, _, _ = models[best_model_idx](perturbed_data)

# Plot original images, Gaussian noise attacked images, and reconstructed Gaussian noise attacked images
plot_images(data.cpu(), perturbed_data.cpu(), recon_batch.cpu())

# %%
# Test performance of reconstruction under Gaussian noise attack by using our model
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# Gaussian noise attack function
def gaussian_noise_attack(data, std):
    noise = torch.randn_like(data) * std
    perturbed_data = data + noise
    perturbed_data = torch.clamp(perturbed_data, 0, 1)
    return perturbed_data

# Plot original images, Gaussian noise attacked images, and reconstructed Gaussian noise attacked images
def plot_images(original_images, perturbed_images, reconstructed_images, n=10):
    original_images = original_images.cpu().numpy()
    perturbed_images = perturbed_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display Gaussian noise attacked images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(perturbed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed Gaussian noise attacked images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze())
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to filter out only the digits 2 and 3
def filter_2_and_3(data, target):
    mask = (target == 2) | (target == 3)
    return data[mask], target[mask]

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Filter out only the digits 2 and 3
data, targets = filter_2_and_3(data, targets)

# Set Gaussian noise attack parameters
std = 0.5  # Noise standard deviation

# Generate adversarial samples using Gaussian noise
perturbed_data = gaussian_noise_attack(data, std)

# Reconstruct adversarial samples
recon_batch, _, _, _, _ = models[best_model_idx](perturbed_data)

# Plot original images, Gaussian noise attacked images, and reconstructed Gaussian noise attacked images
plot_images(data.cpu(), perturbed_data.cpu(), recon_batch.cpu())

# %%
# Test reconstruction of the models under a patch attack
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Define the transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# Remove digits 2 and 3 from the training dataset
train_dataset.data = train_dataset.data[(train_dataset.targets != 2) & (train_dataset.targets != 3)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets != 2) & (train_dataset.targets != 3)]

# Create new data loaders after removing digits 2 and 3
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# Patch attack function
def add_white_bar_to_images(images, bar_width, bar_height, start_x, start_y):
    modified_images = images.clone()
    modified_images[:, :, start_y:start_y+bar_height, start_x:start_x+bar_width] = 1.0
    return modified_images

# Parameters for the white bar
bar_width = 20
bar_height = 10
start_x = 30
start_y = 30

# Plot original images, patched images, and reconstructed images
def plot_images(original_images, patched_images, reconstructed_images, n=10):
    original_images = original_images.cpu().detach().numpy()
    patched_images = patched_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display patched images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(patched_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed patched images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Add white bar to the images
data_with_bar = add_white_bar_to_images(data, bar_width, bar_height, start_x, start_y)

# Pass the images with the white bar through the model
recon_batch_with_bar = models[best_model_idx](data_with_bar)[0]

# Plot the original images, images with the white bar, and their reconstructions
plot_images(data, data_with_bar, recon_batch_with_bar)

# %%
# Test reconstruction of the models under a patch attack
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Define the transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# Remove digits 2 and 3 from the training dataset
train_dataset.data = train_dataset.data[(train_dataset.targets != 2) & (train_dataset.targets != 3)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets != 2) & (train_dataset.targets != 3)]

# Create new data loaders after removing digits 2 and 3
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# Patch attack function
def add_white_bar_to_images(images, bar_width, bar_height, start_x, start_y):
    modified_images = images.clone()
    modified_images[:, :, start_y:start_y+bar_height, start_x:start_x+bar_width] = 1.0
    return modified_images

# Parameters for the white bar
bar_width = 20
bar_height = 10
start_x = 10
start_y = 10

# Plot original images, patched images, and reconstructed images
def plot_images(original_images, patched_images, reconstructed_images, n=10):
    original_images = original_images.cpu().detach().numpy()
    patched_images = patched_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display patched images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(patched_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed patched images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Add white bar to the images
data_with_bar = add_white_bar_to_images(data, bar_width, bar_height, start_x, start_y)

# Pass the images with the white bar through the model
recon_batch_with_bar = models[best_model_idx](data_with_bar)[0]

# Plot the original images, images with the white bar, and their reconstructions
plot_images(data, data_with_bar, recon_batch_with_bar)

# %%
# Test reconstruction of the models under a patch attack
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from skimage.metrics import structural_similarity as ssim

# Define the transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Download and load the MNIST dataset
train_dataset = datasets.MNIST('./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST('./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# Remove digits 2 and 3 from the training dataset
train_dataset.data = train_dataset.data[(train_dataset.targets != 2) & (train_dataset.targets != 3)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets != 2) & (train_dataset.targets != 3)]

# Create new data loaders after removing digits 2 and 3
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=128, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=128, num_workers=4, pin_memory=True)

# Patch attack function
def add_white_bar_to_images(images, bar_width, bar_height, start_x, start_y):
    modified_images = images.clone()
    modified_images[:, :, start_y:start_y+bar_height, start_x:start_x+bar_width] = 1.0
    return modified_images

# Parameters for the white bar
bar_width = 20
bar_height = 10
start_x = 40
start_y = 40

# Plot original images, patched images, and reconstructed images
def plot_images(original_images, patched_images, reconstructed_images, n=10):
    original_images = original_images.cpu().detach().numpy()
    patched_images = patched_images.cpu().detach().numpy()
    reconstructed_images = reconstructed_images.cpu().detach().numpy()

    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Display original images
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(original_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display patched images
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(patched_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed patched images
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(reconstructed_images[i].transpose(1, 2, 0).squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# Function to compute MSE loss
def mse_loss(original, reconstruction):
    return F.mse_loss(reconstruction, original).item()

# Function to compute SSIM loss
def ssim_loss(original, reconstruction):
    original = original.cpu().detach().numpy().transpose(0, 2, 3, 1)
    reconstruction = reconstruction.cpu().detach().numpy().transpose(0, 2, 3, 1)
    ssim_values = [ssim(original[i], reconstruction[i], multichannel=True) for i in range(original.shape[0])]
    return sum(ssim_values) / len(ssim_values)

# Choose a random batch of images from the test dataset
data, targets = next(iter(test_loader))
data, targets = data.to(device), targets.to(device)

# Add white bar to the images
data_with_bar = add_white_bar_to_images(data, bar_width, bar_height, start_x, start_y)

# Pass the images with the white bar through the model
recon_batch_with_bar = models[best_model_idx](data_with_bar)[0]

# Plot the original images, images with the white bar, and their reconstructions
plot_images(data, data_with_bar, recon_batch_with_bar)

# Compute MSE and SSIM loss
mse = mse_loss(data, recon_batch_with_bar)
ssim_val = ssim_loss(data, recon_batch_with_bar)

print(f'MSE Loss: {mse}')
print(f'SSIM Loss: {ssim_val}')
# Out:
# MSE Loss: 0.037663232535123825
# SSIM Loss: 0.871182650161167
